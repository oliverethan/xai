# %%
from deepdreamer import model, load_image, recursive_optimize
import numpy as np
import PIL.Image
# Out:
# maybe_download
# Downloading Inception 5h Model ...
# - Download progress: 100.0%
# Download finished. Extracting files.
# Done.
# WARNING:tensorflow:From /Users/ethanoliver/Documents/cs/xai/deepdream_playground/inception5h.py:101: The name tf.GraphDef is deprecated. Please use tf.compat.v1.GraphDef instead.
#
# WARNING:tensorflow:From /Users/ethanoliver/Documents/cs/xai/deepdream_playground/deepdreamer.py:25: The name tf.GPUOptions is deprecated. Please use tf.compat.v1.GPUOptions instead.
#
# WARNING:tensorflow:From /Users/ethanoliver/Documents/cs/xai/deepdream_playground/deepdreamer.py:26: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /Users/ethanoliver/Documents/cs/xai/deepdream_playground/deepdreamer.py:27: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.

# %%
layer_tensor = model.layer_tensors[3]

# %%
file_name = "ming.png"
img = load_image(filename='{}'.format(file_name))

# %%
img_result = recursive_optimize(layer_tensor=layer_tensor, image=img,
                 # how clear is the dream vs original image
                 num_iterations=20, step_size=1.0, rescale_factor=0.5,
                 # How many "passes" over the data. More passes, the more granular the gradients will be.
                 num_repeats=8, blend=0.2)
# Out:
# Recursive level: 0
# Processing image:
# . . . . . . . . . . . . . . . . . . . . Recursive level: 1
# Processing image:
# . . . . . . . . . . . . . . . . . . . . Recursive level: 2
# Processing image:
# . . . . . . . . . . . . . . . . . . . . Recursive level: 3
# Processing image:
# . . . . . . . . . . . . . . . . . . . . Recursive level: 4
# Processing image:
# . . . . . . . . . . . . . . . . . . . . Recursive level: 5
# Processing image:
# . . . . . . . . . . . . . . . . . . . . Recursive level: 6
# Processing image:
# . . . . . . . . . . . . . . . . . . . . Recursive level: 7
# Processing image:
# . . . . . . . . . . . . . . . . . . . . Recursive level: 8
# Processing image:
# . . . . . . . . . . . . . . . . . . . .

# %%
img_result = np.clip(img_result, 0.0, 255.0)
img_result = img_result.astype(np.uint8)
result = PIL.Image.fromarray(img_result, mode='RGB')
result.save('dream_image_out.jpg')
result.show()

# %%
from matplotlib.pyplot import imshow
imshow(np.asarray(result))

# %%
img_result = recursive_optimize(layer_tensor=layer_tensor, image=img,
                 # how clear is the dream vs original image
                 num_iterations=50, step_size=1.0, rescale_factor=0.5,
                 # How many "passes" over the data. More passes, the more granular the gradients will be.
                 num_repeats=8, blend=0.2)
# Out:
# Recursive level: 0
# Processing image:
# . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . Recursive level: 1
# Processing image:
# . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . Recursive level: 2
# Processing image:
# . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . Recursive level: 3
# Processing image:
# . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . Recursive level: 4
# Processing image:
# . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . Recursive level: 5
# Processing image:
# . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . Recursive level: 6
# Processing image:
# . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . Recursive level: 7
# Processing image:
# . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . Recursive level: 8
# Processing image:
# . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .

# %%
img_result = np.clip(img_result, 0.0, 255.0)
img_result = img_result.astype(np.uint8)
result = PIL.Image.fromarray(img_result, mode='RGB')
result.save('dream_image_40.jpg')
result.show()

# %%
from matplotlib.pyplot import imshow
imshow(np.asarray(result))

# %%
layer_tensor = model.layer_tensors[8]

# %%
img_result = recursive_optimize(layer_tensor=layer_tensor, image=img,
                 # how clear is the dream vs original image
                 num_iterations=50, step_size=1.0, rescale_factor=0.5,
                 # How many "passes" over the data. More passes, the more granular the gradients will be.
                 num_repeats=8, blend=0.2)
# Out:
# Recursive level: 0
# Processing image:
# . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . Recursive level: 1
# Processing image:
# . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . Recursive level: 2
# Processing image:
# . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . Recursive level: 3
# Processing image:
# . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . Recursive level: 4
# Processing image:
# . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . Recursive level: 5
# Processing image:
# . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . Recursive level: 6
# Processing image:
# . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . Recursive level: 7
# Processing image:
# . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . Recursive level: 8
# Processing image:
# . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .

# %%
img_result = np.clip(img_result, 0.0, 255.0)
img_result = img_result.astype(np.uint8)
result = PIL.Image.fromarray(img_result, mode='RGB')
result.save('dream_image_lizard.jpg')
result.show()

from matplotlib.pyplot import imshow
imshow(np.asarray(result))
